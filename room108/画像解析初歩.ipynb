# %%
import cv2
import numpy as np 
#numpyの短縮表現をnpと置いた。再度使う際はnpで良い。

img = cv2.imread("C:/Users/wadat/Python/picture/Lenna.bmp",0)
#-1の場合RGBA、1の場合RGB、0の場合グレースケール

cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

img = cv2.imread("C:/Users/wadat/Python/picture/Lenna.bmp")
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
 # OpenCV は色がGBR順なのでRGB順に並べ替える

plt.imshow(img2)
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("color/siro.jpg",0)
print(img.shape)
#画像の行列

ROI = img[0:960,0:1280]
#範囲選択

hist = cv2.calcHist([ROI],[0],None,[256],[0,256])
#ヒストグラム([画像],[カラー],[マスク],[BIN],[ヒスト範囲])
#カラー：グレースケールであれば[0].カラー画像であればB,G,Rの色相に対応する[0],[1],[2]のどれか
#マスク：表示範囲
#BIN：256段階をどの程度区分けするか
#ヒストグラムの下限上限値

plt.plot(hist,color="black")
# Out:
# (960, 1280)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('color/Lenna.bmp')
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

blur = cv2.blur(img2,(5,5))

plt.subplot(121),plt.imshow(img2),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('Python/picture/siro.jpg',0)
test = cv2.imread('Python/picture/test.bmp',0)


kernel = np.ones((15,15),np.float32)/225
dst = cv2.filter2D(img,-1,kernel)


plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])


plt.show()

import pandas as pd
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

im = np.array(img)
im2 = np.array(dst)
im3 = np.array(test)

x = np.arange(len(im[0]))
y = np.arange(len(im))
X, Y = np.meshgrid(x, y)

fig = plt.figure()

ax = Axes3D(fig)

ax.plot_surface(X, Y, np.array(im))

x = np.arange(len(im2[0]))
y = np.arange(len(im2))
X, Y = np.meshgrid(x, y)

fig = plt.figure()

ax = Axes3D(fig)

ax.plot_surface(X, Y, np.array(im2))

im4 = im3 - im

x = np.arange(len(im4[0]))
y = np.arange(len(im4))
X, Y = np.meshgrid(x, y)

fig = plt.figure()

ax = Axes3D(fig)

ax.plot_surface(X, Y, np.array(im4),cmap = "summer")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-c9a0ddb87226> in <module>
#       8
#       9 kernel = np.ones((15,15),np.float32)/225
# ---> 10 dst = cv2.filter2D(img,-1,kernel)
#      11
#      12
#
# error: OpenCV(4.4.0) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-h4wtvo23\opencv\modules\imgproc\src\filter.dispatch.cpp:1530: error: (-215:Assertion failed) !_src.empty() in function 'cv::filter2D'

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('Lenna.bmp',0)


kernel = np.ones((1,100),np.float32)/100
dst = cv2.filter2D(img,-1,kernel)

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("test.bmp",0)
print(img.shape)

for i in range(200,1200):
    ROI = img[200:210,i:i+1]
    x = i
    y = np.mean(ROI)
    plt.plot(x,y,marker=".",color="#0F0F0F")
# Out:
# (960, 1280)

# %%
# %matplotlib widget
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('C:/Users/wadat/Python/picture/siro.jpg',0)
test = cv2.imread('C:/Users/wadat/Python/picture/test.bmp',0)


kernel = np.ones((15,15),np.float32)/225
dst = cv2.filter2D(img,-1,kernel)


plt.subplot(121),plt.imshow(img)
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst)
plt.xticks([]), plt.yticks([])

plt.show()

import pandas as pd
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

im = np.array(img)
im2 = np.array(dst)
im3 = np.array(test)

x = np.arange(len(im[0]))
y = np.arange(len(im))
X, Y = np.meshgrid(x, y)

fig = plt.figure(figsize=(8,8))

ax = Axes3D(fig)

ax.plot_surface(X, Y, np.array(im))

x = np.arange(len(im2[0]))
y = np.arange(len(im2))
X, Y = np.meshgrid(x, y)

fig = plt.figure(figsize=(8,8))

ax = Axes3D(fig)

ax.plot_surface(X, Y, np.array(im2))

im4 = im - im3

from mpl_toolkits.mplot3d import Axes3D
x = np.arange(len(im4[0]))
y = np.arange(len(im4))
X, Y = np.meshgrid(x, y)
fig = plt.figure()
plt.plot([100,1100],[200,200],lw=5,color='#e41a1c') 
abc = plt.imshow(im4,cmap="gray")
plt.figure()

for i in range(100,1100):
    ROI = im4[200:210,i:i+1]
    x = i
    y = np.mean(ROI)
    plt.plot(x,y,marker=".",color="#0F0F0F")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# -*- coding: utf-8 -*-

import wx


class MyFileDropTarget(wx.FileDropTarget):
    def __init__(self, window):
        wx.FileDropTarget.__init__(self)
        self.window = window

    def OnDropFiles(self, x, y, filenames):
        # ファイルパスをテキストフィールドに表示
        for file in filenames:
            self.window.text.SetValue(file)
        return True


class MyFrame(wx.Frame):
    def __init__(self):
        wx.Frame.__init__(self, None, title="Drop Target", size=(500, 200))
        p = wx.Panel(self)
        sizer = wx.BoxSizer(wx.HORIZONTAL)

        label = wx.StaticText(p, -1, "File name:")
        self.text = wx.TextCtrl(p, -1, "", size=(400, -1))
        sizer.Add(label, 0, wx.ALL, 5)
        sizer.Add(self.text, 0, wx.ALL, 5)
        p.SetSizer(sizer)

        dt = MyFileDropTarget(self)
        self.SetDropTarget(dt)
        self.Show()


if __name__ == '__main__':
    app = wx.App()
    MyFrame()
    app.MainLoop()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-35dcfff228cd> in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 import wx
#       4
#       5
#
# ModuleNotFoundError: No module named 'wx'
